# %%
f = open('txtxt.txt', 'r',errors="ignore")

# %%
ls = []
ls1 = []
for i in range(3657):
    ls1 =[]
    l = f.readline()
    lst = l.split('\t')
    a1 = lst[0]
    a2 = lst[1].split('\n')[0]
    #print(a1,a2)
    if a1 == 'Yes':
        ls1.append(a1)
        ls1.append(a2)
        ls.append(ls1)
        

print(ls)
# Out:
# [['Yes', '-If you want others to help manage your channel, you can add up to 50 people without sharing your password.'], ['Yes', '3. Select the services that you want to add.'], ['Yes', "Also want to talk about your voicemail last night--i.e., I may need to travel with KL, which is fine by me if that's necessary."], ['Yes', 'Also, to be sure that you always receive any emails with important loan information, please add info@info.offerstuff.com'], ['Yes', "And if there's anything else I can do re: your meeting on Monday, don't hesitate."], ['Yes', "And there's no need to pay for individual tracks - you can listen all you want."], ['Yes', 'Apply for a job at AVON today.'], ['Yes', "Apply for a job at Joe's Crab Shack today."], ['Yes', 'Are there other presentations that would useful to look at in preparation for the talk?'], ['Yes', 'As it is a strange and unfamiliar ground for some of us, I thought it appropriate to invite you, on behalf of my brothers, Mohamed and Abdullah, and mysel
# ...

# %%
import csv
f2 = open('sen11.csv','w')
wrt = csv.writer(f2)
wrt.writerow(['sen','label'])
# Out:
# 11

# %%
ls[0][1]
# Out:
# '-If you want others to help manage your channel, you can add up to 50 people without sharing your password.'

# %%
for i in range(len(ls)):
    l = []
    l.append(ls[i][1])
    l.append(2)
    wrt.writerow(l)

# %%
import pandas as pd

# %%
df = pd.read_csv('imperativeSen.csv')

# %%
df
# Out:
#                                                Sentence  Label
# 0      Please forward back with any changes you migh...      2
# 1               Please communicate with Mark Holsworth.      2
# 2      Andy - can you please forward this email to y...      2
# 3                                       please schedule      2
# 4      Could you give me a brief description of what...      2
# ...                                                 ...    ...
# 6524                                Please respond to \      2
# 6525   Please take a look at them and make sure I am...      2
# 6526   Please take a look at the attached and let me...      2
# 6527   Please review the comments (they are only 4 p...      2
# 6528   can you change deal 27 (paribas) today to NYM...      2
#
# [6529 rows x 2 columns]
